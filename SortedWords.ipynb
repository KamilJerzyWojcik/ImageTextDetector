# %%
from main import ImageTextDetector
import matplotlib.pyplot as plt

# %%
imageTextDetector = ImageTextDetector()
path = 'books_images/20191118_180815.jpg'

# %%
image_boxes, images, results = imageTextDetector.get_ordered_words(image_path = path)
# Out:
# Loading weights from checkpoint (../neural_networks/CRAFT/craft_ic15_20k.pth)
# Test image: books_images/20191118_180815.jpg
# elapsed time : 16.978060960769653s
# loading pretrained model from ../neural_networks/TextRecognition/TPS-ResNet-BiLSTM-Attn.pth
# /Users/kamiljerzy/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2693: UserWarning: Default grid_sample and affine_grid behavior will be changed to align_corners=False from 1.4.0. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior will be changed "
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# image_0                  	27                       	0.0935
# image_1                  	pro                      	0.9993
# ...

# %%
results
# Out:
# ['pro', 'publico', 'bono', 'asesor']

# %%
plt.rcParams["figure.figsize"] = (30,15)
plt.imshow(image_boxes, interpolation='none')
plt.show()

# %%
for img in images:
    imgplot = plt.imshow(img)
    plt.show()

# %%
# cv2.imwrite("my.png",img)
