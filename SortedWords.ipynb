# %%
from main import ImageTextDetector
import matplotlib.pyplot as plt

# %%
imageTextDetector = ImageTextDetector()
path = 'books_images/cookbook.jpg'

# %%
image_boxes, images, results = imageTextDetector.get_ordered_words(image_path = path)
# Out:
# Loading weights from checkpoint (../neural_networks/CRAFT/craft_ic15_20k.pth)
# Test image: books_images/cookbook.jpg
# elapsed time : 21.721856117248535s
# loading pretrained model from ../neural_networks/TextRecognition/TPS-ResNet-BiLSTM-Attn.pth
# --------------------------------------------------------------------------------
# image_path               	predicted_labels         	confidence score
# --------------------------------------------------------------------------------
# image_0                  	ja                       	0.9147
# image_1                  	mie                      	0.3161
# image_2                  	il                       	0.2955
# image_3                  	i                        	0.3824
# image_4                  	ve                       	0.9893
# image_5                  	f                        	0.6236
# image_6                  	skladnikow               	0.9892
# image_7                  	kuchnia                  	0.9931
# image_8                  	gotuj                    	0.9997
# image_9                  	szybko                   	0.9997
# image_10                 	i                        	0.6070
# image_11                 	latwo                    	0.9995

# %%
results
# Out:
# ['ja', 've', 'skladnikow', 'kuchnia', 'gotuj', 'szybko', 'latwo']

# %%
plt.rcParams["figure.figsize"] = (30,15)
plt.imshow(image_boxes, interpolation='none')
plt.show()

# %%
plt.rcParams["figure.figsize"] = (10,5)
for img in images:
    imgplot = plt.imshow(img)
    plt.show()

# %%
# cv2.imwrite("my.png",img)
